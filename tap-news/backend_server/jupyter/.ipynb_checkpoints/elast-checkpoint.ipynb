# %%
# make sure ES is up and running
import requests
res = requests.get('http://localhost:9200')
print(res.content)
# Out:
# {
#   "name" : "idAwBkj",
#   "cluster_name" : "elasticsearch",
#   "cluster_uuid" : "GVeWRJgNRZubjiNgz5FQlQ",
#   "version" : {
#     "number" : "5.4.0",
#     "build_hash" : "780f8c4",
#     "build_date" : "2017-04-28T17:43:27.229Z",
#     "build_snapshot" : false,
#     "lucene_version" : "6.5.0"
#   },
#   "tagline" : "You Know, for Search"
# }

# %%
#connect to our cluster
from elasticsearch import Elasticsearch
es = Elasticsearch([{'host': 'localhost', 'port': 9200}])

# %%
import json
import csv
i=1
with open('export.csv') as f:
    reader = csv.DictReader(f)
    rows = list(reader)
    for data in rows:
        es.index(index='news',doc_type='news', id=i, body=data)
        i+=1

# %%
es.get(index='news', doc_type='news', id=5)
# Out:
# {u'_id': u'5',
#  u'_index': u'news',
#  u'_source': {u'author': u'',
#   u'class': u'Politics & Government',
#   u'description': u'ISIS claimed responsibility for bombings that killed dozens at two Coptic churches in Egypt on Palm Sunday.',
#   u'digest': u'qdJ/xxZVsolyndLd+dNn5w==\n',
#   u'publishedAt': u'2017-04-09T22:23:12.000Z',
#   u'source': u'cnn',
#   u'title': u'ISIS claims deadly Egypt church bombings - CNN Video',
#   u'url': u'http://www.cnn.com/videos/world/2017/04/09/egypt-church-bombings-isis-alexandria-tanta-nick-paton-walsh-nr.cnn',
#   u'urlToImage': u'http://i2.cdn.cnn.com/cnnnext/dam/assets/170409094402-01-alexandria-egypt-church-bombing-0409-super-tease.jpg'},
#  u'_type': u'news',
#  u'_version': 1,
#  u'found': True}

# %%
es.search(index="news", body={"query": {"match": {'description':'trump'}}})
# Out:
# {u'_shards': {u'failed': 0, u'successful': 5, u'total': 5},
#  u'hits': {u'hits': [{u'_id': u'2444',
#     u'_index': u'news',
#     u'_score': 3.2474344,
#     u'_source': {u'author': u'https://www.facebook.com/WashingtonPostPlumLine?ref=hl',
#      u'class': u'Other',
#      u'description': u'Huge majorities of Trump voters see the media -- not Trump -- as the dishonest one in the equation.',
#      u'digest': u'hDpl2uhXP/NsNoF4R1sugQ==\n',
#      u'publishedAt': u'2017-04-27T15:19:00.000Z',
#      u'source': u'google-news',
#      u'title': u'Opinion | Trump\u2019s lies are working brilliantly. This new poll proves it.',
#      u'url': u'https://www.washingtonpost.com/blogs/plum-line/wp/2017/04/27/trumps-lies-are-working-brilliantly-this-new-poll-proves-it/',
#      u'urlToImage': u'https://img.washingtonpost.com/rf/image_1484w/2010-2019/WashingtonPost/2017/04/26/National-Economy/Images/667783388.jpg'},
#     u'_type': u'news'},
#    {u'_id': u'2012',
#     u'_index': u'news',
# ...

# %%
es.search(index="news", body={"query": {"more_like_this": 
                                { "fields" : ["title", "description"],"like_text" : "Government","min_term_freq" : 1}}})
# Out:
# {u'_shards': {u'failed': 0, u'successful': 5, u'total': 5},
#  u'hits': {u'hits': [{u'_id': u'2721',
#     u'_index': u'news',
#     u'_score': 5.168561,
#     u'_source': {u'author': u'Erin Kelly',
#      u'class': u'Politics & Government',
#      u'description': u'With just hours left until a government shutdown at midnight, the House passed a stopgap funding bill Friday that will keep the government open for another week.',
#      u'digest': u'KieLrT1jcNrRJdkJRnbLAA==\n',
#      u'publishedAt': u'2017-04-28T15:31:08.000Z',
#      u'source': u'usa-today',
#      u'title': u'House passes short-term funding bill to avoid shutdown, with Senate expected to follow suit',
#      u'url': u'https://www.usatoday.com/story/news/politics/2017/04/28/house-passes-short-term-funding-bill-avoid-shutdown-senate-expected-follow-suit/101018580/',
# ...
